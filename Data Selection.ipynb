# %%
### Install Google Play Scraper

# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\bhagaskara\anaconda3\lib\site-packages (1.2.3)

# %% [markdown]
# # Import Library

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %% [markdown]
# # Scraping Data

# %%
# scrap available review

from google_play_scraper import Sort, reviews

result, continuation_token  = reviews (
'com.gojek.app',
lang= 'id', 
country= 'id', 
sort= Sort.NEWEST,
count= 20000, 
filter_score_with= None
)

# %%
df_gojek = pd.DataFrame(np.array(result),columns=['review']) 

df_gojek = df_gojek.join(pd.DataFrame(df_gojek.pop('review').tolist()))

df_gojek.head()
# Out:
#                                reviewId                  userName  \
# 0  2b37d459-adcc-4442-b135-46f569c5dd04                 Robbi Eko
# 1  acf0ebc8-63b9-4a3b-a04f-a8cfc9dcd80a                mimi cedar
# 2  e64f2aa7-2256-4a08-9fea-bf2f084d3812  Elisabeth Kiswati Ladiyo
# 3  7d49c997-d5e7-48fd-914b-3a0ad964bf44       Jemmi Meliau ibanez
# 4  50b19d75-52e7-41d8-a0db-efa823dbdca5               Boedi Arsih
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ACB-R...
# 1  https://play-lh.googleusercontent.com/a-/ACB-R...
# 2  https://play-lh.googleusercontent.com/a-/ACB-R...
# 3  https://play-lh.googleusercontent.com/a/AGNmyx...
# 4  https://play-lh.googleusercontent.com/a/AGNmyx...
#
#                                              content  score  thumbsUpCount  \
# 0                              sip... terima kasih 🙏      5              0
# 1  Bagaimana cara transfer sesama Gopay. Gopay sa...      5              0
# 2      Aman,dan cepat. Sesuai dengan ekspektasi.👍🏼👍🏼      5              0
# 3                     . aplikasi yang cukup membantu      5              0
# 4                                    Cepet sampainya      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0               4.63.2 2023-03-30 14:37:38         None       NaT
# 1               4.64.2 2023-03-30 14:35:59         None       NaT
# 2               4.64.2 2023-03-30 14:33:41         None       NaT
# 3               4.64.2 2023-03-30 14:23:25         None       NaT
# 4               4.64.2 2023-03-30 14:19:13         None       NaT

# %%
df_gojek.tail()
# Out:
#                                    reviewId            userName  \
# 19995  66fb6fb3-338a-4e7f-bbfc-d78346285c2d                NS P
# 19996  43acca6a-d207-4ef7-97ad-3f3480f6cb6e          EGA ARDANA
# 19997  c11b6d22-f557-4fff-b9ef-d47b30be593d  Andre Jayaramadhan
# 19998  1b2c7d23-5ed2-4297-954c-e3721d70b697          Angga Dian
# 19999  827df1c0-4b49-4d66-b82c-143cf238c9fc         Sri Rastini
#
#                                                userImage  \
# 19995  https://play-lh.googleusercontent.com/a-/ACB-R...
# 19996  https://play-lh.googleusercontent.com/a-/ACB-R...
# 19997  https://play-lh.googleusercontent.com/a/AGNmyx...
# 19998  https://play-lh.googleusercontent.com/a-/ACB-R...
# 19999  https://play-lh.googleusercontent.com/a-/ACB-R...
#
#                                                  content  score  \
# 19995         tolong di peringan app nya, suka ngelag...      5
# 19996  Gman nih gw mau upgrade gopay dh puluhan kali ...      1
# 19997  Perbaiki lagi apk nya, mau to up gopay aja nun...      1
# 19998                                            Mantaap      5
# 19999  aplikasi yang Baik, sangat membantu saya,makas...      5
#
#        thumbsUpCount reviewCreatedVersion                  at  \
# 19995              0               4.58.1 2023-01-08 15:30:18
# 19996              0                 None 2023-01-08 15:29:57
# 19997              0                 None 2023-01-08 15:27:11
# 19998              0               4.58.1 2023-01-08 15:20:19
# 19999              0               4.58.1 2023-01-08 15:11:35
#
#                                             replyContent           repliedAt
# 19995                                               None                 NaT
# 19996  Hai Ega, maaf atas kendala yang dialami. Sebel... 2023-01-09 10:39:15
# 19997  Hai Andre, maaf atas kendala yang kamu alami. ... 2023-01-09 10:40:16
# 19998                                               None                 NaT
# 19999                                               None                 NaT

# %%
len(df_gojek.index)
# Out:
# 20000

# %%
data_new = df_gojek[['userName', 'score', 'at', 'content']]
data_new.head()
# Out:
#                  userName  score                  at  \
# 19995                NS P      5 2023-01-08 15:30:18
# 19996          EGA ARDANA      1 2023-01-08 15:29:57
# 19997  Andre Jayaramadhan      1 2023-01-08 15:27:11
# 19998          Angga Dian      5 2023-01-08 15:20:19
# 19999         Sri Rastini      5 2023-01-08 15:11:35
#
#                                                  content
# 19995         tolong di peringan app nya, suka ngelag...
# 19996  Gman nih gw mau upgrade gopay dh puluhan kali ...
# 19997  Perbaiki lagi apk nya, mau to up gopay aja nun...
# 19998                                            Mantaap
# 19999  aplikasi yang Baik, sangat membantu saya,makas...

# %%
data_new = df_gojek[['userName', 'score', 'at', 'content']]
data_new.tail()
# Out:
#                  userName  score                  at  \
# 19995                NS P      5 2023-01-08 15:30:18
# 19996          EGA ARDANA      1 2023-01-08 15:29:57
# 19997  Andre Jayaramadhan      1 2023-01-08 15:27:11
# 19998          Angga Dian      5 2023-01-08 15:20:19
# 19999         Sri Rastini      5 2023-01-08 15:11:35
#
#                                                  content
# 19995         tolong di peringan app nya, suka ngelag...
# 19996  Gman nih gw mau upgrade gopay dh puluhan kali ...
# 19997  Perbaiki lagi apk nya, mau to up gopay aja nun...
# 19998                                            Mantaap
# 19999  aplikasi yang Baik, sangat membantu saya,makas...

# %%
#save data to folder
data_new.to_csv("datagojek.csv", index=False)

path = '/Documents/Analisis Sentimen Gojek/Data'
